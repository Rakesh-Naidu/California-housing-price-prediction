# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
from sklearn import datasets
dt = datasets.fetch_california_housing()
print(type(dt))# this returns you a bunch object
print(dt.DESCR)#accessing key as attributes from bunch
# Out:
# <class 'sklearn.utils.Bunch'>
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# ...

# %%
df = pd.DataFrame(dt.data,columns=dt.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
df['Price'] = pd.Series(dt.target)

# %%
# Dropping Latitude and Longitude - Independent Variables
df.drop(columns=['Latitude','Longitude'],inplace=True)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Price'],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis
# - Continuous

# %%
sns.displot(df['Price'])

# %%
sns.boxplot(x='Price',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
sns.displot(df['MedInc'])

# %%
sns.boxplot(x='MedInc',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
sns.boxplot(x='MedInc',data=df,showmeans=True,meanline=True,showfliers=False)

# %%
sns.displot(df['HouseAge'])

# %%
sns.boxplot(x='HouseAge',data=df,showmeans=True,meanline=True,showfliers=False)

# %%
sns.displot(df['AveRooms'])

# %%
sns.boxplot(x='AveRooms',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
sns.boxplot(x='AveRooms',data=df,showmeans=True,meanline=True,showfliers=False)

# %%
sns.displot(df['AveBedrms'])

# %%
sns.boxplot(x='AveBedrms',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
sns.boxplot(x='AveBedrms',data=df,showmeans=True,meanline=True,showfliers=False)

# %%
sns.displot(df['Population'])

# %%
sns.boxplot(x='Population',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
sns.boxplot(x='Population',data=df,showmeans=True,meanline=True,showfliers=False)

# %%
sns.displot(df['AveOccup'])

# %%
sns.boxplot(x='AveOccup',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
sns.boxplot(x='AveOccup',data=df,showmeans=True,meanline=True,showfliers=False)

# %% [markdown]
# ## Bivariate Analysis
# - cont vs cont

# %%
sns.scatterplot(x=df['MedInc'],y=df['Price'])

# %%
sns.regplot(x=df['MedInc'],y=df['Price'])

# %%
sns.scatterplot(x=df['HouseAge'],y=df['Price'])

# %%
sns.regplot(x=df['HouseAge'],y=df['Price'])

# %%
sns.scatterplot(x=df['AveRooms'],y=df['Price'])

# %%
sns.regplot(x=df['AveRooms'],y=df['Price'],ci=False)

# %%
sns.scatterplot(x=df['AveBedrms'],y=df['Price'])

# %%
sns.regplot(x=df['AveBedrms'],y=df['Price'],ci=False)

# %%
sns.scatterplot(x=df['Population'],y=df['Price'])

# %%
sns.regplot(x=df['Population'],y=df['Price'],ci=False)

# %%
sns.scatterplot(x=df['AveOccup'],y=df['Price'])

# %%
sns.regplot(x=df['AveOccup'],y=df['Price'],ci=False)

# %%
sns.pairplot(df)

# %% [markdown]
# ## Data Wrangling
# ### Outliers Treatment

# %%
sns.boxplot(x='MedInc',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
df['MedInc'] = np.sqrt(df['MedInc'])
q = df["MedInc"].quantile(0.98)
df = df[df["MedInc"]<q]
q = df["MedInc"].quantile(0.02)
df = df[df["MedInc"]>q]

# %%
df.shape
# Out:
# (19822, 7)

# %%
sns.boxplot(x='AveRooms',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
df['AveRooms'] = np.sqrt(df['AveRooms'])
q = df["AveRooms"].quantile(0.98)
df = df[df["AveRooms"]<q]
q = df["AveRooms"].quantile(0.02)
df = df[df["AveRooms"]>q]

# %%
df.shape
# Out:
# (19036, 7)

# %%
sns.boxplot(x='AveBedrms',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
df['AveBedrms'] = np.sqrt(df['AveBedrms'])
q = df["AveBedrms"].quantile(0.95)
df = df[df["AveBedrms"]<q]
q = df["AveBedrms"].quantile(0.05)
df = df[df["AveBedrms"]>q]

# %%
df.shape
# Out:
# (17179, 7)

# %%
sns.boxplot(x='Population',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
df['Population'] = np.sqrt(df['Population'])
q = df["Population"].quantile(0.98)
df = df[df["Population"]<q]
q = df["Population"].quantile(0.02)
df = df[df["Population"]>q]

# %%
df.shape
# Out:
# (16498, 7)

# %%
sns.boxplot(x='AveOccup',data=df,showmeans=True,meanline=True,showfliers=True)

# %%
df['AveOccup'] = np.sqrt(df['AveOccup'])
q = df["AveOccup"].quantile(0.95)
df = df[df["AveOccup"]<q]
q = df["AveOccup"].quantile(0.05)
df = df[df["AveOccup"]>q]

# %%
df.shape
# Out:
# (14889, 7)

# %%
sns.boxplot(x='MedInc',data=df)

# %%
sns.boxplot(x='AveRooms',data=df)

# %%
sns.boxplot(x='AveBedrms',data=df)

# %%
sns.boxplot(x='Population',data=df)

# %%
sns.boxplot(x='AveOccup',data=df)

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.to_csv("housing.csv",index=False)
